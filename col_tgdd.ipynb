# %%
from bs4 import BeautifulSoup
import requests
import time
import requests
import pandas as pd
import csv

url = "https://www.thegioididong.com/dtdd/"

payload = ""
headers = {
    'cache-control': "no-cache",
    'Postman-Token': "5dafbb63-6b28-4aeb-9b0f-08c9a9078843"
    }

response = requests.request("GET", url, data=payload, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
list = soup.find('ul', {'class': 'homeproduct'}).find_all('li')
print(len(list))
# Out:
# 29

# %%
html = None
with open('./dt.html', 'r', encoding='utf8') as f:
    html = f.read()
soup = BeautifulSoup(html, 'html.parser')
myuls = soup.find_all('li')
print(myuls)

# %%
mylist

# %%
from bs4 import BeautifulSoup
import requests
import time
import requests
import pandas as pd

html = None
with open('./dt.html', 'r',  encoding='utf8') as f:
    html = f.read()

soup = BeautifulSoup(html, 'html.parser')
myuls = soup.find_all('li')

url = "https://www.thegioididong.com"

payload = ""
headers = {
    'cache-control': "no-cache",
    'Postman-Token': "5dafbb63-6b28-4aeb-9b0f-08c9a9078843"
    }

response = requests.request("GET", url, data=payload, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
mylist = soup.find('ul', {'class': 'homeproduct'}).find_all('li')

array_product = []

for li in myuls:
    link = url + li.find('a')['href']
    print(link)
    headers = {
        'cache-control': "no-cache",
        'postman-token': "3b6342a3-5388-3805-f686-9b9bc2d92632"
    }
    response = requests.request("GET", link, headers=headers)

    htmldt = response.text
    soupdt = BeautifulSoup(htmldt, 'html.parser')
    try:    
        id_p = soupdt.find('div', {'class': 'area_order'}).find('a')['data-value']
    except:
        id_p = None
    try:
        product_name = soupdt.find('div', {'class': 'rowtop'}).find('h1').text
    except:
        product_name = None
    try:
        price = soupdt.find('div', {'class': 'area_price'}).find('strong').text
    except:
        price: None
    try: 
        rating = int(soupdt.find('div', {'class': 'ratingresult'}).find('a').text.split()[0])
    except:
        rating = None
    try:
        link_image = soupdt.find('div', {'class': 'rowdetail'}).find('img')['src']
    except:
        link_image = None
    dict = {
        'id_p': id_p,
        'product_name': product_name,
        'price': price,
        'rating': rating,
        'link_image': link_image
    }
    
    array_product.append(dict)
# Out:
# https://www.thegioididong.com/dtdd/samsung-galaxy-a9-2018
# https://www.thegioididong.com/dtdd/iphone-xr
# https://www.thegioididong.com/dtdd/huawei-mate-20-pro
# https://www.thegioididong.com/dtdd/oppo-find-x
# https://www.thegioididong.com/dtdd/samsung-galaxy-s9-plus-128gb
# https://www.thegioididong.com/dtdd/iphone-8-plus
# https://www.thegioididong.com/dtdd/samsung-galaxy-note8
# https://www.thegioididong.com/dtdd/samsung-galaxy-s9-plus

# %%
array_product

# %%
import dateparser

# %%
def get_review(product_id, rate_nums, score=0):
  reviews = []
  for page in list(range(1, round(rate_nums/3)+2)):
    try:
      url = "https://www.thegioididong.com/aj/ProductV4/RatingCommentList/"

      payload = f"------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"productid\"\r\n\r\n{product_id}\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"page\"\r\n\r\n{page}\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"score\"\r\n\r\n{score}\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
      headers = {
          'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
          'cache-control': "no-cache",
          'postman-token': "dd07aa72-96d3-e32e-fdd5-61566f93043d"
      }

      response = requests.request("POST", url, data=payload, headers=headers)
      soup = BeautifulSoup(response.text, 'html.parser')
      mylis = soup.find_all('li', {'class': 'par'})
      for li in mylis:
        rated_content = li.find('p').find('i', recursive=False).text
        rated_num = len(li.find('p').find('span').find_all('i', {'class': 'iconcom-txtstar'}))
        rated_date = dateparser.parse(li.find('a', {'class': 'cmtd'}).text, languages=['vi']).strftime("%d/%m/%Y")
        reviews.append({
            'content': rated_content,
            'num_star': rated_num,
            'date': rated_date
        })
      
    except:
      pass
  return reviews

# %%
def get_reviews(product_id, rating_nums, score=0):
    reviews = []
    for page in range(1, round(rating_nums/3) + 2):
        try:
            url = "https://www.thegioididong.com/aj/ProductV4/RatingCommentList"

            payload = f"------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"productid\"\r\n\r\n{product_id}\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"{page}\"\r\n\r\n12\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"{score}\"\r\n\r\n0\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
            headers = {
                'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
                'cache-control': "no-cache",
                'postman-token': "bcd83aaf-f2aa-ea8b-ab0c-d6f2f7bc744e"
                }

            response = requests.request("POST", url, data=payload, headers=headers)
            soup = BeautifulSoup(response.text, 'html.parser')
            for li in mylis:
                rated_content = li.find('p').find('i', recursive=False).text
                rated_num = len(li.find('p').find('span').find_all('i', {'class': 'iconcom-txtstar'}))
                rated_date = dateparser.parse(li.find('a', {'class': 'cmtd'}).text, languages=['vi']).strftime("%d/%m/%Y")
                reviews.append({
                    'content': rated_content,
                    'num_star': rated_num,
                    'date': rated_date
                })
        except:
            pass
    return reviews

# %%
get_review('183994', 40)

# %%
import requests

url = "https://www.thegioididong.com/aj/ProductV4/RatingCommentList"

payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"productid\"\r\n\r\n163645\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"page\"\r\n\r\n3\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"score\"\r\n\r\n0\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'cache-control': "no-cache",
    'postman-token': "12a112ec-24f2-3dcf-74df-2c57562c6d40"
    }

response = requests.request("POST", url, data=payload, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
mylist = soup.find_all('li', {'class': 'par'})
mylist[0].find('p').find('i',  recursive=False).text
dateparser.parse(mylist[0].find('a', {'class': 'cmtd'}).text, languages=['vi']).strftime("%d/%m/%Y")

# %%
import csv
array_reviews = []
with open('rate_file.csv', 'w', encoding = 'utf8') as rate_file:
    rating_file = csv.writer(rate_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for dtdt in array_product:
        try:
            rating_file.writerow(get_review(dtdt['id_p'], dtdt['rating']))
        except:
            pass

# %%
import csv
with open('rate_file.csv', 'w', encoding = 'utf8') as rate_file:
    rating_file = csv.writer(rate_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    rating_file.writerow(['Name', 'Reviews', 'Num_Start', 'Date'])
   
    for dtdt in array_product:
        reviews = get_review(dtdt['id_p'], dtdt['rating'])
        for cmt in reviews:
            print(cmt)
            try:
                rating_file.writerow([dtdt['product_name'], cmt['content'], cmt['num_star'], cmt['date']])
            except:
                pass

# %%
get_review('183994', 40)

# %%
import csv

with open('employee_file.csv', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    employee_writer.writerow(['John Smith', 'Accounting', 'November'])
    employee_writer.writerow(['Erica Meyers', 'IT', 'March'])

# %%
array_rating

# %%
for rate in array_product[:5]:
    print(rate)

# %%
# !pip install dateparser

# %%
# !python -m pip install --upgrade pip

# %%
# !pip install PyHamcrest

# %%
import csv

with open('employee_file.csv', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    employee_writer.writerow(['John Smith', 'Accounting', 'November'])
    employee_writer.writerow(['Erica Meyers', 'IT', 'March'])

# %%
for page in range(1, round(10/3) + 2):
    print(page)

# %%
import pandas as pd

# %%
pd.read_csv('rate_file.csv')
pd.set_option()
# Out:
#                                     Name  \
# 0    Điện thoại Samsung Galaxy A9 (2018)
# 1    Điện thoại Samsung Galaxy A9 (2018)
# 2    Điện thoại Samsung Galaxy A9 (2018)
# 3    Điện thoại Samsung Galaxy A9 (2018)
# 4    Điện thoại Samsung Galaxy A9 (2018)
# 5    Điện thoại Samsung Galaxy A9 (2018)
# 6    Điện thoại Samsung Galaxy A9 (2018)
# 7    Điện thoại Samsung Galaxy A9 (2018)
# 8    Điện thoại Samsung Galaxy A9 (2018)
# 9    Điện thoại Samsung Galaxy A9 (2018)
# 10   Điện thoại Samsung Galaxy A9 (2018)
# 11   Điện thoại Samsung Galaxy A9 (2018)
# 12   Điện thoại Samsung Galaxy A9 (2018)
# 13   Điện thoại Samsung Galaxy A9 (2018)
# 14   Điện thoại Samsung Galaxy A9 (2018)
# 15   Điện thoại Samsung Galaxy A9 (2018)
# 16   Điện thoại Samsung Galaxy A9 (2018)
# 17   Điện thoại Samsung Galaxy A9 (2018)
# 18   Điện thoại Samsung Galaxy A9 (2018)
# 19   Điện thoại Samsung Galaxy A9 (2018)
# 20   Điện thoại Samsung Galaxy A9 (2018)
# 21   Điện thoại Samsung Galaxy A9 (2018)
# 22   Điện thoại Samsung Galaxy A9 (2018)
# 23   Điện thoại Samsung Galaxy A9 (2018)
# 24   Điện thoại Samsung Galaxy A9 (2018)
# 25   Điện thoại Samsung Galaxy A9 (2018)
# 26   Điện thoại Samsung Galaxy A9 (2018)
# 27   Điện thoại Samsung Galaxy A9 (2018)
# 28   Điện thoại Samsung Galaxy A9 (2018)
# 29   Điện thoại Samsung Galaxy A9 (2018)
# ..                                   ...
# 502   Điện thoại Samsung Galaxy S9+ 64GB
# 503   Điện thoại Samsung Galaxy S9+ 64GB
# 504   Điện thoại Samsung Galaxy S9+ 64GB
# 505   Điện thoại Samsung Galaxy S9+ 64GB
# 506   Điện thoại Samsung Galaxy S9+ 64GB
# 507   Điện thoại Samsung Galaxy S9+ 64GB
# 508   Điện thoại Samsung Galaxy S9+ 64GB
# 509   Điện thoại Samsung Galaxy S9+ 64GB
# 510   Điện thoại Samsung Galaxy S9+ 64GB
# 511   Điện thoại Samsung Galaxy S9+ 64GB
# 512   Điện thoại Samsung Galaxy S9+ 64GB
# 513   Điện thoại Samsung Galaxy S9+ 64GB
# 514   Điện thoại Samsung Galaxy S9+ 64GB
# 515   Điện thoại Samsung Galaxy S9+ 64GB
# 516   Điện thoại Samsung Galaxy S9+ 64GB
# 517   Điện thoại Samsung Galaxy S9+ 64GB
# 518   Điện thoại Samsung Galaxy S9+ 64GB
# 519   Điện thoại Samsung Galaxy S9+ 64GB
# 520   Điện thoại Samsung Galaxy S9+ 64GB
# 521   Điện thoại Samsung Galaxy S9+ 64GB
# 522   Điện thoại Samsung Galaxy S9+ 64GB
# 523   Điện thoại Samsung Galaxy S9+ 64GB
# 524   Điện thoại Samsung Galaxy S9+ 64GB
# 525   Điện thoại Samsung Galaxy S9+ 64GB
# 526   Điện thoại Samsung Galaxy S9+ 64GB
# 527   Điện thoại Samsung Galaxy S9+ 64GB
# 528   Điện thoại Samsung Galaxy S9+ 64GB
# 529   Điện thoại Samsung Galaxy S9+ 64GB
# 530   Điện thoại Samsung Galaxy S9+ 64GB
# 531   Điện thoại Samsung Galaxy S9+ 64GB
#
#                                                Reviews  Num_Start        Date
# 0    Máy ổn. Camera tốt .mặt lưng đẹp Chơi PUPG Liê...          5  13/12/2018
# 1    Rất ổn, mọi thứ đều mượt mà, sạc nhanh, máy đẹ...          5  12/12/2018
# 2    Điều thất vọng nhất là không có Samsung Pay (d...          3  11/12/2018
# 3    May quá m lấy máy thấy cũng ổn. Mầu màn hình h...          3  10/12/2018
# 4    May quá m lấy m thấy cũng ổn. Nhưng mầu mè màn...          3  10/12/2018
# 5    Máy đẹp, nghe nhạc hay, màn hình to nên xem ph...          5  10/12/2018
# 6    Máy ok về mọi thứ, pin để qua đêm chỉ hụt 1% ,...          5  10/12/2018
# 7    máy bình thường chụp hình k được thật cho lắm ...          3  10/12/2018
# 8    Mới tậu 1 tiếng. Lướt êm mượt. Chụp hình xấu, ...          1  10/12/2018
# 9    Máy quảng cáo hoành tráng nên khi sử dụng đã k...          3  10/12/2018
# 10   Ta hên nhận được máy ngon, ko lỗi, bin trâu, k...          5  10/12/2018
# 11   Pin 3800 mAh nhưng tụt nhanh quá không như mon...          1  10/12/2018
# 12   Máy mượt, to bảng, xem phim, chơi game tốt.\nM...          5  10/12/2018
# 13   Máy không xứng tầm giá bán, đèn led thông báo ...          2  10/12/2018
# 14   Tốt so với giá dành cho một chiếc điện thoại t...          4  03/12/2018
# 15   Máy tụt pin quá nhanh. Để qua 1 đêm mà tụt tới...          3  03/12/2018
# 16   Em xin có 1 vài ý kiến sau khi dùng sp a9 đc v...          4  03/12/2018
# 17   Nói chung ok trừ vỏ bằng nhựa . K có đèn báo đ...          3  03/12/2018
# 18   Ok mà không có đèn led thông báo với pin mau h...          3  03/12/2018
# 19   Sản phẩm thiết kế đẹp, dùng mượt với các ứng d...          4  03/12/2018
# 20   Hài lòng. Chỉ thấy pin tụt hơi nhanh, hi vọng ...          5  03/12/2018
# 21   Giá quá cao so với chất lương !!\nPin mau tuột...          1  11/12/2018
# 22   Mọi thứ điều tốt phải chi có thêm chống nước c...          5  10/12/2018
# 23   Mới lấy con A9 được 2 ngày nói chung tất cả đi...          5  10/12/2018
# 24   Máy sài ok ko có vấn đề gi vừa nc zalo vơi vk ...          5  10/12/2018
# 25   Camera 24mp mà ko đẹp như mong đợi, thấy thất ...          3  10/12/2018
# 26   Rất tuyệt vời máy dùng mượt không lỗi lầm gì,p...          5  10/12/2018
# 27   Màn hình to, pin dùng ổn, camera tạm được. Dùn...          5  10/12/2018
# 28   Điện thoại Mau hết pin quá chụp hình ko khật. ...          1  10/12/2018
# 29   Máy tụt pin quá nhanh, camera chụp hình ko thậ...          1  10/12/2018
# ..                                                 ...        ...         ...
# 502  Màn hình hiển thị rất đẹp, sắc nét và có chiều...          5  21/03/2018
# 503  Thời lượng pin ko ổn rồi pin 3500 cứ bấm bấm v...          4  19/11/2018
# 504  Máy sài rất thích, nhưng pin xuống nhanh quá. ...          4  19/11/2018
# 505  Máy đẹp, sài êm, âm thanh chuẩn rất thích khi ...          5  15/11/2018
# 506  S9 pplus tụt pin nhanh hơn so voi s8 plus. Cùn...          5  12/11/2018
# 507  Thiết kế rất đẹp, chụp hình rất đẹp, pin trâu,...          5  07/11/2018
# 508  Mỗi tội là pin cũng hơi nhanh xuống, còn lại t...          5  27/10/2018
# 509  Sản phẩm cực tốt.Màn hình nét, chơi game mượt,...          5  25/10/2018
# 510  sản phẩm dùng rất thích, pin khỏe, thiết kế đẹ...          4  20/09/2018
# 511  Nói chung là mọi thứ trên s9 plus rất tốt nhưn...          5  19/09/2018
# 512  Máy này dùng khá ok. màn hình rộng xem youtube...          4  11/09/2018
# 513  Đã mua tại TGDĐ được hơn 2 tháng và trãi nghiệ...          5  13/08/2018
# 514  Mình đã dùng nó từ tháng 4/2018 đến nay là đượ...          5  11/08/2018
# 515  Mua từ tháng 3 và không có gì để chê. Máy màu ...          5  11/08/2018
# 516  Nhờ thiết kế tràn viền, tổng thể S9 Plus vẫn đ...          3  07/08/2018
# 517  Mình có chụp hình máy S9+ màu đen 64Gb\nNhưng ...          1  17/07/2018
# 518  Tuyệt vời lắm. Xứng đáng là 1 siêu phẩm 2018. ...          5  24/06/2018
# 519  Đã mua S9+ sanh san hô tại thế giới di động là...          5  14/06/2018
# 520  Máy xài rất tốt, mượt mà, màn hình sắc nét, ch...          5  01/06/2018
# 521  Chưa coa gì phàn nàn cả. Càng sài pin càng trâ...          5  01/06/2018
# 522  Sản phẩm đẹp, gọn, dùng là loại màng hình supe...          4  27/05/2018
# 523  Good.các tỉnh năng dt phần mềm hoạt động tốt ....          5  22/05/2018
# 524  Camera ngày ổn tối hơi nhiễu _pin vừa cảm ứng ...          5  21/05/2018
# 525  Màn hình hiển thị rất đẹp, sắc nét và có chiều...          5  08/05/2018
# 526  Mình đã sử dụng được 2 tuần rồi, rất là tuyệt ...          5  08/04/2018
# 527  Đã xài thử S9 và thấy rất hài lòng, thiết kế n...          5  05/04/2018
# 528  Quá tuyệt vời pin zai rất tốt chụp ảnh rất đẹp...          1  01/04/2018
# 529  Chưa sử dụng nhưng thấy samsung s9 plus tốt về...          5  30/03/2018
# 530  Mọi thứ đều ổn nhưng pin thì quá tệ,sạc thì nh...          5  21/03/2018
# 531  Mình đã mua và sử dụng , thật sự rất tuyệt vời...          5  16/03/2018
#
# [532 rows x 4 columns]
